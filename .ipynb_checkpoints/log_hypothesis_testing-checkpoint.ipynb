# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df_condtn=pd.read_csv('/content/condtn_merged.csv',index_col=[0])
df1 = pd.DataFrame(df_condtn['Avg_activity'])
fig, axs = plt.subplots(nrows=1, ncols=2)
df1=np.log(df1)
df_condtn['Avg_activity']=df1
df_condtn
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#       SI.NO        date  hour  Avg_activity  status
# 0         1  2003-05-07    12      5.848027       1
# 1         1  2003-05-07    13      5.650979       1
# 2         1  2003-05-07    14      5.631857       1
# 3         1  2003-05-07    15      5.388067       1
# 4         1  2003-05-07    16      5.474579       1
# ...     ...         ...   ...           ...     ...
# 9209     23  2002-06-28     5          -inf       1
# 9210     23  2002-06-28     6          -inf       1
# 9211     23  2002-06-28     7          -inf       1
# 9212     23  2002-06-28     8          -inf       1
# 9213     23  2002-06-28     9      5.146098       1
#
# [9214 rows x 5 columns]

# %%
df_control=pd.read_csv('/content/control_merged.csv',index_col=[0])
df2 = pd.DataFrame(df_control['Avg_activity'])
df2=np.log(df2)
df_control['Avg_activity']=df2
df_control
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#        SI.NO        date  hour  Avg_activity  status
# 0          1  2003-03-18    15      5.052928       0
# 1          1  2003-03-18    16      5.578030       0
# 2          1  2003-03-18    17      7.007718       0
# 3          1  2003-03-18    18      5.824908       0
# 4          1  2003-03-18    19      6.341822       0
# ...      ...         ...   ...           ...     ...
# 17011     32  2003-04-23     8      1.348073       0
# 17012     32  2003-04-23     9          -inf       0
# 17013     32  2003-04-23    10      1.593309       0
# 17014     32  2003-04-23    11      0.425268       0
# 17015     32  2003-04-23    12      1.244155       0
#
# [17016 rows x 5 columns]

# %%
df_condtn.replace(-np.inf, 0,inplace=True)
df_control.replace(-np.inf, 0,inplace=True)
df_control=df_control.dropna()
df_condtn=df_condtn.dropna()

# %%
df_control
f=pd.DataFrame(df_control['Avg_activity'])
# axs[1].hist(f,edgecolor='black')

# %%
condtn_avg=df_condtn.Avg_activity
condtn_avg=np.array(condtn_avg)
print(condtn_avg)
# Out:
# [5.84802711 5.65097927 5.63185674 ... 0.         0.         5.14609815]

# %%
control_avg=df_control.Avg_activity
control_avg=np.array(control_avg)
print(control_avg)
# Out:
# [5.05292821 5.57803027 7.00771825 ... 1.59330853 0.42526774 1.24415459]

# %%
n1 = len(condtn_avg)
n2 = len(control_avg)

# %%
normalized_condtn=condtn_avg
normalized_control=control_avg

# %%
x1_bar = np.mean(normalized_condtn)
x2_bar = np.mean(normalized_control)

# %%
s1 = np.std(condtn_avg, ddof=1)
s2 = np.std(control_avg, ddof=1)

# %%
print("Basic Statistics from the data")
print("Number of condition sample:", n1, "Number of control sample:", n2)
print("condition mean:", x1_bar, "control mean:", x2_bar)
print("condtn_std:", s1, "control_std:", s2)
# Out:
# Basic Statistics from the data
# Number of condition sample: 9214 Number of control sample: 17016
# condition mean: 3.7625615160124704 control mean: 3.3122708999001533
# condtn_std: 2.0899178022925424 control_std: 2.5269186801367582

# %%
def ztest_ind(X1, X2, mudiff, std_dev_1, std_dev_2, n1, n2):
    from numpy import sqrt, abs, round
    from scipy.stats import norm
    pooled_SE = sqrt(std_dev_1**2/n1 + std_dev_2**2/n2)
    z = ((X1 - X2) - mudiff)/pooled_SE
    if (z<0):
        p=stats.norm.cdf(z)
    else:
        p=1-stats.norm.cdf(z)

    pval = 2*p
    return round(z, 3), round(pval, 20)

# %%
z_statistics, p_value = ztest_ind(x1_bar,x2_bar, 0, s1, s2, n1, n2)
print("Z-statistics: ", z_statistics)
print("P-value: ", p_value)
# Out:
# Z-statistics:  15.451
# P-value:  0.0
